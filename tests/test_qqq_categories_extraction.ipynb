# %%
# %pip install yfinance

# %%
from pyspark.sql import SparkSession
from src.etl.extraction.qqq_categories_extraction import QQQCategoriesExtractor

spark = SparkSession.builder.getOrCreate()

symbols = ["AAPL", "MSFT", "NVDA"]

extractor = QQQCategoriesExtractor(spark)
df = extractor.extract(symbols)

display(df)

# %%
# %sql
SELECT *
FROM silver.qqq_silver_entities
WHERE sector IS NOT NULL
LIMIT 20;

# %%
# %sql
SELECT COUNT(*) FROM silver.fred_indicators;

# %%
# %sql
DROP TABLE IF EXISTS silver.fred_indicators;
